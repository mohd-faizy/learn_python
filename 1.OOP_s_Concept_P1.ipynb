# %% [markdown]
# # OOPs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# -  **Class** is the basic unit of the Object oritented programming
# - **Class** refer to a blue print which can have the **Data & Methods**.
#
# - Using the **class** we can craete the **Objects**.
#
# - So **Objects** is the instace of the class & each **Object** can have its  own data.
#
# - **Ojbect** store the state of some kind.
# -  In the **procedural programming** there is no relation between the **data** & **Method**. thery are treated as the separte entaties.
#
# - **Functions**define inside the class are known as the **Methods**.

# %%
'''
Creating the class in Python
'''

class Car():
    pass            # Empty Class with Empty Method

 # Creating the instances of classes

ford  = Car()
honda = Car()
audi  = Car()

# Associating the data with the objects 

ford.speed  = 200 # Speed is the attribute here 
honda.speed = 220
audi.speed  = 250 

ford.color  = 'red' # Color is the atribute here
honda.color = 'blue'
audi.color  = 'black' 

# We can also change the values of the atttributes
ford.speed = 300
ford.color = 'blue'

# Printinf the attributes
print(ford.speed)
print(ford.color)
# Out:
# 300
# blue

# %%
class Rectangle:
    pass

# Creating the objects 
rect1 = Rectangle()
rect2 = Rectangle()

# Attributes of the Rectangle 

# Height
rect1.height = 20
rect2.height = 40

# Width
rect1.width = 40
rect2.width = 10

# Calculatin the area  of the  Rectangle
print(rect1.height * rect1.width)
print(rect2.height * rect2.width)
# Out:
# 800
# 400

# %% [markdown]
# Adding the Methods to the **Class** & using these methods to minuplate this data

# %%
'''
|--------------------------------------------------------------------|
|<Using __init__ and slef in class>                                  |
|--------------------------------------------------------------------|
-> The __init__ serves as the constructer for the class.
-> It is used to initilize some attributes & function.
-> As this is the first Method to call when we create the instance of the class
'''

class Car():
    def __init__(self):
        print("the __init__ is called")

 # Creating the instances of classes

ford  = Car()
honda = Car()
audi  = Car()

# Associating the data with the objects 

ford.speed  = 200 # Speed is the attribute here 
honda.speed = 220
audi.speed  = 250 

ford.color  = 'red' # Color is the atribute here
honda.color = 'blue'
audi.color  = 'black' 

# We can also change the values of the atttributes
ford.speed = 300
ford.color = 'blue'

# Printing the attributes
print(ford.speed)
print(ford.color)
# Out:
# the __init__ is called
# the __init__ is called
# the __init__ is called
# 300
# blue

# %% [markdown]
# This line `the __init__ is called` is called three times becoz we have created the same instance from the same class three times.
#
# - `__init__` is not the constructer, but it behaves as a constructer.
#
# - Unlike the other languages the python dont have any **Distructer** as python has an automatic garbage collection management.

# %%
 class Car():
    def __init__(self, speed, color):
        self.speed = speed                #Self keyword is used to set the attribute of speed
        self.color = color                #self keyword is udef to set the attribute of color
        

 # Creating the instances of classes

ford  = Car(200, 'red')   #Self aargument is automatically provoided here 
honda = Car(220, 'blue')
audi  = Car(250, 'black')

# Printing the attributes
print(ford.speed)
print(ford.color)
# Out:
# 200
# red

# %%
class Rectangle:

    def __init__(self, height, width):
        self.height = height
        self.width  = width

# Creating the objects 
rect1 = Rectangle(20, 60)
rect2 = Rectangle(50, 70)

# Calculatin the area  of the  Rectangle
print(rect1.height * rect1.width)
print(rect2.height * rect2.width)
# Out:
# 1200
# 3500

# %%
class Rectangle:

    def __init__(self, height, width):
        self.height = height
        self.width  = width
    
    def area(self):
        return (self.height * self.width)
        
        

# Creating the objects 
rect1 = Rectangle(20, 60)
rect2 = Rectangle(50, 70)

# Calculatin the area  of the  Rectangle
print("the area of reac1 is ", rect1.area())
print("the area of reac2 is ", rect2.area())
# Out:
# the area of reac1 is  1200
# the area of reac2 is  3500

# %%
class hello:
    def __init__():
        pass
    def __init__(self, name):
        pass
        
hallo = hello()

# %% [markdown]
# $Note$
#
# In the code above  it is not possible to provide the multiple __init__ method in python class.
# -  if we define multiple `__init__ `in the class, the `__init__` **we define at the last** is will be considerd as the **main** `__init__` method, & the other will be  overwritten.

# %%
class Hello:
    def __init__(self, name = 'Max'):
        pass

hello = Hello()
hello = Hello('name')

# %%
class hello:
    def __init__(self, name):
        pass
    def __init__(self):
        pass
        
hallo = hello('name')

# %% [markdown]
# ```
# TypeError: __init__() takes 1 positional argument but 2 were given
# ```
# The reson for this error is that:
# - The `__init__` in the line No. 4
# will take only the self argumnet & nothing else.
#
# - But in the line No.-7 the self is provided automatically but here we are also providing an addional paramater along with the self.
#
# - Since only the last `__init__ ` is the valid function & hence the error.

# %%
# Example *args

def multiply(*args):
    z = 1
    for num in args:
        z *= num
    print(z)

multiply(4, 5)
multiply(10, 9)
multiply(2, 3, 4)

# %% [markdown]
# To pass multiple parameter to a funcion we can use `*args`.
#
# - *args kind of means any number of arguments
#
# - *args is basically used when you are not sure on the number of arguments that will be passed to your method. This is how you can handle that case using *args.
#
# What `*args` allows you to do is
# take in more arguments than the number of formal arguments that you previously defined. With *args, any number of extra arguments can be tacked on to your current formal parameters (including zero extra arguments).

# %%
class Hello:
    def __init__(self, *args):
        pass

hello = Hello()
hello = Hello('name')
hello = Hello('name', 'class', 'roll no', 'address', 'father name ')

# %%
class Hello:
    def __init__(self, **kwargs):
        pass

hello = Hello()
hello = Hello(name = "faziy", class_jamia = "M_tech", roll_no = "10", address = 'jamia')

# %% [markdown]
# In the code line-2 we are using the `*kwargs` which means any number of arguments with keywords.
#
# - that means the arguments will take the key value pair.
#
# - **kwargs is used when we want to provide the dictionary.

# %% [markdown]
# Hence we can use these varible length arguments when we have pass the multiple arguments in the class

# %%
def print_values(**kwargs):
    for key, value in kwargs.items():
        print("The value of {} is {}".format(key, value))

print_values(
    name_1="Alex",
    name_2="Gray",
    name_3="Harper",
    name_4="Phoenix",
    name_5="Remy",
    name_6="Val"
)
# Out:
# The value of name_1 is Alex
# The value of name_2 is Gray
# The value of name_3 is Harper
# The value of name_4 is Phoenix
# The value of name_5 is Remy
# The value of name_6 is Val

# %%
'''
|--------------------------------------------------------------------|
|Fix this Code                                                       |
|--------------------------------------------------------------------|
'''

class Student:
    def __init__(self, **kwargs):
        pass

    def print_values(**kwargs):
        for key, value in kwargs.items():
            print("The value of {} is {}".format(key, value))


print_values(name = "faizy",
             class_jamia = "M_tech",
             roll_no = "10",
             address = 'jamia'
             )
# Out:
# The value of name is faizy
# The value of class_jamia is M_tech
# The value of roll_no is 10
# The value of address is jamia

# %% [markdown]
# **Where to Use Args and Kwargs**
#
# - ***Args*** and ***kwargs***  are useful when we want to:
#
# 1. Reduce code rewriting.
# 2. Make your code readable.
# 3. Reuse your code

# %%
def add(*args):
    total = 0
    for arg in args:
        total+=arg
    return total

#Scenario 1
print(add(1,2,5,7))
# Out:
# 15

# %%
def func(*args):
    # *args means for however many arguments you take in, it will catch them all
 
    for arg in args:
        return arg
     
 
l = [11,3,4,5,"tuts"]
 
print(func(l))
# Out:
# [11, 3, 4, 5, 'tuts']

# %%
def capital_cities(**kwargs): 
    # initialize an empty list to store the result

    result = []

    for key, value in kwargs.items():
        result.append("The capital city of {} is {}" .format (key,value))
    return result

print(capital_cities(China = "Beijing",Cairo = "Egypt",Rome = "Italy"))
# Out:
# ['The capital city of China is Beijing', 'The capital city of Cairo is Egypt', 'The capital city of Rome is Italy']

# %%
class Student:
    def __init__(self, name):
        self.name = name 
        self.age = 10

s1 = Student('age')
s1.age()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-78856d88e321> in <module>()
#       5
#       6 s1 = Student('age')
# ----> 7 s1.age()
#
# TypeError: 'int' object is not callable

# %%
# code Fix

class Student:

    def __init__(self):
        self.name = "faizy"  
        self.age = 10

    def bio_data(self):
        print("The name of the student is ", self.name, self.age)
    
print(s1.name)
print(s1.age)
# Out:
# faizy
# 10

# %% [markdown]
# # Encapsulation

# %%
class Car:
    def __init__(self, speed, color):
        self.speed = speed 
        self.color = color

    def set_speed(self, value): # To set the speed
        self.speed = value
    
    def get_speed(self):        # To get the speed
        return self.speed

ford  = Car(200, 'red')
honda = Car(220, 'blue')
audi  = Car(250, 'green')

ford.set_speed(300)
ford.speed = 400

print('the new speed of the Ford car is', ford.get_speed())
# Out:
# the new speed of the Ford car is 400

# %% [markdown]
# **Note** - That in line No.- 6 if we replace `value` with the parameter speed the program will then genrate the error.

# %% [markdown]
# And if use the code
#
# `ford.speed = 400` in line No- 17, an then Execute the code. the speed changes to a new value, that is the data is not private.

# %% [markdown]
# So we can use double underscore to make oure code private.

# %% [markdown]
# Hence we cannot change the speed of the varible using code `ford.__speed = 400`

# %%
class Car:
    
    def __init__(self, speed, color):
        self.__speed = speed 
        self.__color = color

    def set_speed(self, value) :  # To set the speed
        self.__speed = value
    
    def get_speed(self):          # To get the speed
        return self.__speed

    def set_color(self, value):  # To set the color
        self.__color = value
    
    def get_color(self):          # To get the color
        return self.__color

ford  = Car(200, 'red')
honda = Car(220, 'blue')
audi  = Car(250, 'green')

ford.set_speed(300)
ford.__speed = 400

ford.set_color('ornage')
ford.__color = 'black'

print('the new speed of the Ford car is', ford.get_speed())
print('the new color of the Ford car is', ford.get_color())
# Out:
# the new speed of the Ford car is 300
# the new color of the Ford car is ornage

# %% [markdown]
# So this method of restricting the data acess using the function is called the **Encapsulation.**
#
# - Hence the private member varible is private to the class.
# - We cannot acess the  private member varible outside the class.

# %%
'''
|--------------------------------------------------------------------|
|Encapsulation: used to hide our data                                |
|--------------------------------------------------------------------|
'''
class Rectangle:

    def __init__(self, height, width):
        self.__height = height    # Access Modifier 
        self.__width  =  width

    def set_height(self, height):
        self.__height = height

    def get__height(self):
        return self.__height

    def set_width(self, width):
        self.__width = width
    
    def get_width(self):
        return self.__width

    def area(self):
        return (self.__height * self.__width)

rect1 = Rectangle(20, 60)
rect2 = Rectangle(30, 90)

# we can call the area notaion directly print the result

print(rect1.area())
print(rect2.area())
# Out:
# 1200
# 2700

# %% [markdown]
# In the code above if we try to acess the privae varible outside the class.
# - it will genrate the error
#
# ```
# 'Object has no attribute inside the class'
# ```
#
# - It's becoz when ever we create an instance and if the member varible is private then this private member varible insvbible to our object.
#
# - **hence we cannot acess the private member varible Outside the class.**
#
# - But Can we acess the private member varible inside the class.
#
#
# ```
# check the code below
# ```

# %%
class Hello:
    def __init__(self, name):
        self.a    = 10
        self._b   = 20
        self .__c = 30

    def public_method(self):
        self.__c;
        print('public')

hello = Hello('name')
print(hello.a)
print(hello._b)
hello.public_method()

#print(hello._c) -- Error
# Out:
# 10
# 20
# public

# %% [markdown]
# ```
# ---> 16 print(hello._c)
#
# AttributeError: 'Hello' object has no attribute '_c'
# ```

# %%
class Hello:
    def __init__(self, name):
        self.a    = 10
        self._b   = 20
        self .__c = 30

    def public_method(self):
        print(self.a)
        print(self.__c)
        print('public')

hello = Hello('name')
print(hello.a)
print(hello._b)
hello.public_method()

#print(hello._c) -- Error
# Out:
# 10
# 20
# 10
# 30
# public

# %% [markdown]
# - Defining the Private method in the class.
# - In ths code we are trying to access the Private Method Outside  the class

# %%
class Hello:

    def __init__(self, name):
        self.a    = 10
        self._b   = 20
        self .__c = 30

    def public_method(self):
        print(self.a)
        print(self.__c)
        print('public')
        self.__private_method()

    def __private_method(self):
        print('private')
         

hello = Hello('name')

print(hello.a)
print(hello._b)


hello.public_method()
# Out:
# 10
# 20
# 10
# 30
# public
# private

# %% [markdown]
# # Inheritance

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# we will need to establish relationships between the **classes** that we build. These relationships can then be established using either **inheritance** or **composition**.

# %% [markdown]
# $Inheritance$
#
# **What is Inheritance?**
#
# **Inheritance** allows One class to gain all the members(say **attributes** and **methods**)of another class. **Inheritance** provides **code reusability**, makes it easier to create and maintain an application. The class from which we are inheriting is called **super-class** and the class that is inherited is called a **derived / child class**.
#
# How to achieve Inheritance in Python

# %%
class Rocket:
    
    def __init__(self, name, distance):
        self.name = name
        self.distance = distance

    def launch(self):
        return "%s has reached %s" % (self.name, self.distance)


class MarsRover(Rocket): # inheriting from the base class
    def __init__(self, name, distance, maker):
        Rocket.__init__(self, name, distance)
        self.maker = maker

    def get_maker(self):
        return "%s Launched by %s" % (self.name, self.maker)


if __name__ == "__main__":
    x = Rocket("simple rocket", "till stratosphere")
    y = MarsRover("mars_rover", "till Mars", "ISRO")
    print(x.launch())
    print(y.launch())
    print(y.get_maker())
# Out:
# simple rocket has reached till stratosphere
# mars_rover has reached till Mars
# mars_rover Launched by ISRO

# %%
# Creating the ploygon class(Super Class)

class Polygon:
# Initalsing the Varible
    height = None # None = Nothing
    width  = None 

#defining Methode
    def Set_value(self, height, width):
        self.__height = height
        self.__width  = width

# Definiong the Sub-classes
class Rectangle(Polygon):
    def area(self):
        return (self.__height * self.__width)

class Triangle(Polygon):
    def area(self):
        return (self.__height * self.__width/2

'''
- For Inheriting the propertires of super-class
we have to use the the parenthesis  with  the
class plygon inside.

- When a sub-class inherite from super-class, the
super-class Methods and varible are accessible using 
the sub-class also.

Note: An instance is an object in memory. Basically 
you create object and instantiate them when you are
using them.

'''
# Creating the Insatances 
rect = Rectangle()
tri  = Triangle( )

rect.Set_value(20, 60)
tri.Set_value(90, 30)

'''
Set valuse is setting the value of the height and
width inside the polygon class

'''
print(rect.area())
print(tri.area())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ba8da1e8cfc6> in <module>()
#      45
#      46 '''
# ---> 47 print(rect.area())
#      48 print(tri.area())
#
# <ipython-input-33-ba8da1e8cfc6> in area(self)
#      13 class Rectangle(Polygon):
#      14     def area(self):
# ---> 15         return (self.__height() * self.__width())
#      16
#      17 class Triangle(Polygon):
#
# AttributeError: 'Rectangle' object has no attribute '_Rectangle__height'

# %% [markdown]
# When we run the above code it will genrate an error.
# ```
# AttributeError: 'Rectangle' object has no attribute '_Rectangle__height'
# ```
# The Error is due to the fact becoz these height & width are the private member of the ploygon class. Hence They are not acessable from the sub-class.
#
# - we cannot inherite the the private member from the super-class to the sub-class.

# %%
# To fix the above Problm we can use the setter & getter

class Polygon:
# Initalsing the Varible
    height = None
    width  = None 

#defining Methode
    def Set_value(self, height, width):
        self.__height = height
        self.__width  = width

    def get_height(self):
        return self.__height

    def get_width(self):
       return self.__width


# Definiong the Sub-classes
class Rectangle(Polygon):
    def area(self):
        return self.get_height() * self.get_width()    
       
         

class Triangle(Polygon):
  
    def area(self):
        return self.get_height() * self.get_width()/2


# Creating the Insatances 
rect = Rectangle()
tri  = Triangle()

rect.Set_value(20, 60)
tri.Set_value(90, 30)

print('The Area of reactangle is', rect.area())
print('The Area of Triangle is', tri.area())
# Out:
# The Area of reactangle is 1200
# The Area of Triangle is 1350.0

# %% [markdown]
# putting the pranthesis infront of the
#
#
# ```
# self.__height()
# ```
# will invoke the method & hence the error is genrated
#
#
# ```
# def get_height(self):
#         return self.__height()
#
#     def get_width(self):
#         return self.__width()
#
# TypeError: 'int' object is not callable
#
# ```

# %%
'''
Using the array
''' 

class Polygon:
# Initalsing the Varible
    height = None
    width  = None 

#defining Methode
    def Set_value(self, height, width):
        self.__height = height
        self.__width  = width

    def get_values(self):
        return [self.__height, self.__width]
 
# Definiong the Sub-classes
class Rectangle(Polygon):

    def area(self): 
        return (self.get_values()[0] * self.get_values()[1])
         
class Triangle(Polygon):
    def area(self):
         return self.get_values()[0] * self.get_values()[1]/2


# Creating the Insatances 
rect = Rectangle()
tri  = Triangle()

rect.Set_value(20, 60)
tri.Set_value(90, 30)

print('The Area of reactangle is', rect.area())
print('The Area of Triangle is', tri.area())
# Out:
# 1200
# 1350.0

# %%
'''
Using the dictionary
'''
class Polygon:
# Initalsing the Varible
    height = None
    width  = None 

# Defining Methode
    def Set_value(self, height, width):
        self.__height = height
        self.__width  = width

    def get_value(self):
        return {'height':self.__height, 'width':self.__width}


# Definiong the Sub-classes
class Rectangle(Polygon):
    
    def area(self):
        data = self.get_value()
        return data['height'] * data['width']

class Triangle(Polygon):
   
    def area(self):
        data = self.get_value()
        return data['height'] * data['width']/2


# Creating the Insatances 
rect = Rectangle()
tri  = Triangle()

rect.Set_value(20, 60)
tri.Set_value(90, 30)

print('The Area of reactangle is', rect.area())
print('The Area of Triangle is', tri.area())
# Out:
# The area of reactangle is 1200
# The Area of Triangle is 1350.0

# %% [markdown]
# # Modules

# %% [markdown]
# A module is a Python object with arbitrarily named attributes that you can bind and reference. Simply, a module is a file consisting of Python code. A module can define functions, classes and variables. A module can also include runnable code.

# %%
class Parent1:

    def __init__(self, name):
       print('Parent __init__', name)

class Parent2:

    def __init__(self, name):
       print('Parent2 __init__', name)

class Child(Parent2, Parent1):

    def __init__(self):
        print('Child __init__')
        super().__init__('max')

'''
The super() builtin returns a proxy object that allows
you to refer parent class by 'super'. In Python, super()
built-in has two major use cases: Allows us to avoid using
base class explicitly. Working with Multiple Inheritance.
'''

child = Child()
print(Child.__mro__)

'''
In Python, a class can inherit features and attributes from 
multiple classes and thus, implements multiple inheritance. 
MRO or Method Resolution Order is the hierarchy in which base
classes are searched when looking for a method in the parent class.
'''
# Out:
# Child __init__
# Parent2 __init__ max
# (<class '__main__.Child'>, <class '__main__.Parent2'>, <class '__main__.Parent1'>, <class 'object'>)
# '\nIn Python, a class can inherit features and attributes from \nmultiple classes and thus, implements multiple inheritance. \nMRO or Method Resolution Order is the hierarchy in which base\nclasses are searched when looking for a method in the parent class.\n'

# %% [markdown]
# There are some rules based on which this order is calculated.
# `(<class '__main__.Child'>, <class '__main__.Parent'>, <class 'object'>)
# `
# - The first rule is he Method inside the sub-class is alaways called first.
#
# - & Then whatever is inside the base-class that is called.

# %%
class Parent1:

    def __init__(self, name):
       print('Parent __init__', name)

class Parent2:

    def __init__(self, name):
       print('Parent2 __init__', name)

class Child(Parent2, Parent1):

    def __init__(self):
        print('Child __init__')
        super().__init__('max')

child = Child()
print(Child.__mro__)
# Out:
# Child __init__
# Parent2 __init__ max
# (<class '__main__.Child'>, <class '__main__.Parent2'>, <class '__main__.Parent1'>, <class 'object'>)
# '\nIn Python, a class can inherit features and attributes from \nmultiple classes and thus, implements multiple inheritance. \nMRO or Method Resolution Order is the hierarchy in which base\nclasses are searched when looking for a method in the parent class.\n'

# %%
class Parent:

    def __init__(self, name):
       self.name = name
       print('Parent __init__', name)

class Child(Parent):

    def __init__(self):
        print('Child __init__')

prsn1 = Parent('faizy')

print(prsn1.name)
prsn1.name = 'Ajaz'
print(prsn1.name)
# Out:
# Parent __init__ faizy
# faizy
# Ajaz

# %% [markdown]
# This is called the Resource ID
#
# ```
# <__main__.Child object at 0x7fd757eaf940>
# ```

# %% [markdown]
# # Operater overloading

# %% [markdown]
# **Operator Overloading** means giving extended meaning beyond their predefined operational meaning.
# - **For example** operator + is used to add two integers as well as join two strings and merge two lists. It is achievable because ‘+’ operator is overloaded by int class and str class.
#
# - We have also have noticed that the same built-in operator or function shows different behavior for objects of different classes, this is called **Operator Overloading.**

# %%
# Python program to show use of 
# '*' & '+' operator for different purposes. 

print(type(2))

print(type(2.0))

print(type('faziy'))

print(1 + 2) 
  
# concatenate two strings 
print("mohd" + "_Faizy")  

  
# concatenate two number
print('1' + '2') 
  
# Product two numbers 
print(4 * 4) 
  
# Repeat the String 
print("_Faizy" * 4) 

'''
Hence in the above code both the operater is overloaded for handling the 
different type of data this is known as Operater overloading.
'''
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# 3
# mohd_Faizy
# 12
# 16
# _Faizy_Faizy_Faizy_Faizy

# %% [markdown]
# **Can we Overload our operaters with the custom** **class**

# %%
class Number:
    def __init__(self, num):
        self.num = num

n1 = Number(1)
n2 = Number(2)
n1 + n2

# %%
class A:
    pass
dir(A)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
import math

class Circle:
    def __init__(self, radius):
        self.__radius = radius
    
    def set_radius(self, radius):
        self.__radius = __radius
    
    def get_radius(self):
        return self.__radius
    
    def area(self):
        return math.pi * self.__radius ** 2

c1 = Circle(2)
c2 = Circle(3)

print(c1.area())
print(c2.area())
# Out:
# 12.566370614359172
# 28.274333882308138

# %%
import math

class Circle:
    def __init__(self, radius):
        self.__radius = radius
    
    def set_radius(self, radius):
        self.__radius = __radius
    
    def get_radius(self):
        return self.__radius
    
    def area(self):
        return math.pi * self.__radius ** 2


c1 = Circle(2)
c2 = Circle(3)
c1 + c2

# %% [markdown]
# ```
# ---> 18 c1 + c2
#
# TypeError: unsupported operand type(s) for +: 'Circle' and 'Circle'
# ```

# %%
import math
 
class Circle:
 
    def __init__(self, radius):
        self.__radius = radius
 
    def setRadius(self, radius):
        self.__radius = radius
 
    def getRadius(self):
        return self.__radius
 
    def area(self):
        return math.pi * self.__radius ** 2
 
    def __add__(self, another_circle): # another Circle is 'c3'
        return Circle( self.__radius + another_circle.__radius )
 
c1 = Circle(4) 
c2 = Circle(5)

# Another Circle 
c3 = c1 + c2
# This became possible because we have overloaded '+'operator by adding a    method named __add__

print(c1.getRadius())
print(c2.getRadius())
print(c3.getRadius())

print(c1.area())
print(c2.area())
print(c3.area())
# Out:
# 4
# 5
# 9
# 50.26548245743669
# 78.53981633974483
# 254.46900494077323

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We have already seen We can use +  operator for adding numbers and at the same time to concatenate strings.
#
# - It is possible because +  operator is overloaded by both int  class and str  class.
#
# - The operators are actually methods defined in respective classes. Defining methods for operators is known as operator overloading.
#
# - For e.g. To use +  operator with custom objects  you need to define a method called `__add__  .`

# %%
# Program below is using some of the above mentioned functions to overload operators.

import math

class Circle:

    def __init__(self, radius):
        self.__radius = radius

    def setRadius(self, radius):
        self.__radius = radius

    def getRadius(self):
        return self.__radius

    def area(self):
        return math.pi * self.__radius ** 2

    def __add__(self, another_circle):
        return Circle(self.__radius + another_circle.__radius)

    def __gt__(self, another_circle):
        return self.__radius > another_circle.__radius

    def __lt__(self, another_circle):
        return self.__radius < another_circle.__radius

    def __str__(self):
        #return "Circle with radius " + str(self.__radius)
        return "Area of the Circle = " + str(self.area())

c1 = Circle(4)
print(c1.getRadius())

c2 = Circle(5)
print(c2.getRadius())

c3 = c1 + c2
print(c3.getRadius())

print( c3 > c2) # Became possible because we have added __gt__ method

print( c1 > c2) # Became possible because we have added __lt__ method

print(c3) # Became possible because we have added __str__ method

dir(c1) #Represent the list of  the fucntion that we can implement inside  our class.

print(str(c1))
# Out:
# 4
# 5
# 9
# True
# False
# Area of the Circle = 254.46900494077323
# Area of the Circle = 50.26548245743669

# %%
class Salary:

    def __init__(self, pay, bonus):
        self.pay   = pay
        self.bonus = bonus

    def annual_salary(self):
        return (self.pay * 12) + self.bonus 

'''
we cannot have the inheritance here, As salary & Employee is
two different thing, But we can use the composition here -->
which means that we are deligating the responsibility from 
one class to another class 
'''
class Employee:

    def __init__(self, name, age, pay, bonus):
        self.name = name 
        self.age  = age
        self.obj_salary = Salary(pay, bonus)
        
    def tolal_salary(self):
        return self.obj_salary.annual_salary()

'''
here we are using the Salary class inside the Employee class
--> here the class Employee acts as a Container for the class
Salary which act as the content.
'''
emp = Employee('faizy', 28, 20000, 10000)
print('The Salary of the Employee is', emp.tolal_salary())

'''
Employee class has deligated the its responsibility to the Salary
class which gives us the annual salary of an Employee this is Known
composition 
'''
# Out:
# The Salary of the Employee is 250000

# %% [markdown]
# **What is composition?**
#
# In composition, we do not inherit from the base class but establish relationships between classes through the use of instance variables that are references to other objects.
#
# **How to achieve composition in Python?**
#
# To achieve composition you can instantiate other objects in the class and then use those instances.

# %% [markdown]
# Composition is a way of aggregating objects together by making some objects attributes of other objects. we can make a `datetime.date` object an attribute of our Person object, and use it to store a person’s birthdate. We can say that a person has a birthdate – if we can express a relationship between two classes using the phrase **has-a**, it is a **composition** relationship.

# %% [markdown]
# ```
# class GenericClass:
#     define some attributes and methods
#
# class ASpecificClass:
#     Instance_variable_of_generic_class = GenericClass
#
# # use this instance somewhere in the class
#     some_method(Instance_variable_of_generic_class)
# ```

# %%
class Rocket:

    def __init__(self, name, distance):
        self.name = name
        self.distance = distance

    def launch(self):
        return "%s has reached %s" % (self.name, self.distance)


class MarsRover(Rocket): # inheriting from the base class

    def __init__(self, name, distance, maker):
        Rocket.__init__(self, name, distance)
        self.maker = maker

    def get_maker(self):
        return "%s Launched by %s" % (self.name, self.maker)

class MarsRoverComp():

    def __init__(self, name, distance, maker):
        self.rocket = Rocket(name, distance) # instantiating the base
        self.maker = maker

    def get_maker(self):
        return "%s Launched by %s" % (self.rocket.name, self.maker)

if __name__ == "__main__":
    x = Rocket("simple rocket", "till stratosphere")
    y = MarsRover("mars_rover", "till Mars", "ISRO")
    z = MarsRover("mars_rover2", "till Mars", "ISRO")
    
    print(x.launch())
    print(y.launch())

    print(y.get_maker())

    print(z.launch())
    print(z.get_maker())
# Out:
# simple rocket has reached till stratosphere
# mars_rover has reached till Mars
# mars_rover Launched by ISRO
# mars_rover2 has reached till Mars
# mars_rover2 Launched by ISRO

# %% [markdown]
# $Aggregation$

# %%
class Salary:

    def __init__(self, pay, bonus):
        self.pay   = pay
        self.bonus = bonus

    def annual_salary(self):
        return (self.pay * 12) + self.bonus 

class Employee:

    def __init__(self, name, age, salary):
        self.name = name 
        self.age  = age
        self.obj_salary = salary
        
    def total_salary(self):
        return self.obj_salary.annual_salary()

salary = Salary(15000, 10000)
emp = Employee('faizy', 28, salary)
print('The Salary of the Employee is', emp.total_salary())
# Out:
# The Salary of the Employee is 190000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aggregation:**
# ```
# class B:
#     pass
#
# class A(object):
#     def __init__(self):
#         self.B = B
# ```
# **Composition:**
#
# ```
# class A(object):
#     def __init__(self, B):
#         self.B = B
# ```

# %% [markdown]
# *To create a class A which receives an instance of class B (aggregation), you could write the following:*
#
#
#
# ```
# class B(object):
#     pass
#
# class A(object):
#     def __init__(self, b):
#         self.b = b
#
# b = B()
# a = A(b)

# %% [markdown]
# According to some formal definitions the term **composition** implies that the two objects are quite strongly linked – one object can be thought of as belonging exclusively to the other object. If the owner object ceases to exist, the owned object will probably cease to exist as well. If the link between two objects is weaker, and neither object has exclusive ownership of the other, it can also be called **aggregation.**
#
# - **Aggregation** : **Has a** Employee has a salary
#
# - **Composition** : **Part of** --> Salary is a part of Employee

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Creating the Abstract classes in Python**

# %%
from abc import ABC, abstractclassmethod 

'''
ABC: Abstract base class --> this allow us to create the Abstract base class in 
python 
'''
class Shape(ABC):
    @abstractclassmethod  # these decorater makes this method abstract Method
    def area(self):
        pass

    @abstractclassmethod  
    def perimeter(self):
        pass
class Square(Shape):
    def __init__(self, side):
        self.__side = side

    def area(self):
        return self.__side * self.__side
    
    def perimeter(self):
        return 4 * self.__side

'''these abstract method convert our class to abstract class 
hence we cannot use this --> shape = Shape() --- directly'''

square = Square(5)

print(square.area())
print(square.perimeter())
# Out:
# 25
# 20

# %% [markdown]
# # Debugging Exercise

# %%
# Here are four classes which show several examples of aggregation and composition:

class Student:
    def __init__(self, name, student_number):
        self.name = name
        self.student_number = student_number
        self.classes = []

    def enrol(self, course_running):
        self.classes.append(course_running) 
        course_running.add_student(self)


class Department:
    def __init__(self, name, department_code):
        self.name = name
        self.department_code = department_code
        self.courses = {}

    def add_course(self, description, course_code, credits):
        self.courses[course_code] = Course(description, course_code, credits, self)
        return self.courses[course_code]


class Course:
    def __init__(self, description, course_code, credit, department):
        self.description = description
        self.course_code = course_code
        self.credits = credits
        self.department = department
        self.department.add_course(self)

        self.runnings = []

    def add_running(self, year):
        self.runnings.append(CourseRunning(self, year))
        return self.runnings[-1]


class CourseRunning:
    def __init__(self, course, year):
        self.course = course
        self.year = year
        self.students = []

    def add_student(self, student):
        self.students.append(student)


ece_dept = Department("electronics", "MEL")
ece_jmi = ece_dept.add_course("Electronics", "ECE101", 6)
ece_jmi_2019 = ece_jmi.add_running(2017)

faizy = Student("Rahul", "Faizy")
faizy.enrol(ece_jmi_2019)

# %%
# simple example of inheritance:

class Person:
    def __init__(self, name, surname, number):
        self.name = name
        self.surname = surname
        self.number = number


class Student(Person):
    UNDERGRADUATE, POSTGRADUATE = range(2)

    def __init__(self, student_type, *args, **kwargs):
        self.student_type = student_type
        self.classes = []
        super(Student, self).__init__(*args, **kwargs)

    def enrol(self, course):
        self.classes.append(course)


class StaffMember(Person):
    PERMANENT, TEMPORARY = range(2)

    def __init__(self, employment_type, *args, **kwargs):
        self.employment_type = employment_type
        super(StaffMember, self).__init__(*args, **kwargs)


class Lecturer(StaffMember):
    def __init__(self, *args, **kwargs):
        self.courses_taught = []
        super(Lecturer, self).__init__(*args, **kwargs)

    def assign_teaching(self, course):
        self.courses_taught.append(course)


jane = Student(Student.POSTGRADUATE, "Jane", "Smith", "SMTJNX045")
jane.enrol(a_postgrad_course)

bob = Lecturer(StaffMember.PERMANENT, "Bob", "Jones", "123456789")
bob.assign_teaching(an_undergrad_course)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f3c982095ddf> in <module>()
#      37
#      38 jane = Student(Student.POSTGRADUATE, "Jane", "Smith", "SMTJNX045")
# ---> 39 jane.enrol(a_postgrad_course)
#      40
#      41 bob = Lecturer(StaffMember.PERMANENT, "Bob", "Jones", "123456789")
#
# NameError: name 'a_postgrad_course' is not defined

# %%
#multiple Inheritances

class Person:
    def __init__(self, name, surname, number):
        self.name = name
        self.surname = surname
        self.number = number


class LearnerMixin:
    def __init__(self):
        self.classes = []

    def enrol(self, course):
        self.classes.append(course)


class TeacherMixin:
    def __init__(self):
        self.courses_taught = []

    def assign_teaching(self, course):
        self.courses_taught.append(course)


class Tutor(Person, LearnerMixin, TeacherMixin):
    def __init__(self, *args, **kwargs):
        super(Tutor, self).__init__(*args, **kwargs)

jane = Tutor("Jane", "Smith", "SMTJNX045")
jane.enrol(a_postgrad_course)
jane.assign_teaching(an_undergrad_course)

# %%
# Replacing inheritance with composition
class Learner:
    def __init__(self):
        self.classes = []

    def enrol(self, course):
        self.classes.append(course)


class Teacher:
    def __init__(self):
        self.courses_taught = []

    def assign_teaching(self, course):
        self.courses_taught.append(course)


class Person:
    def __init__(self, name, surname, number, learner=None, teacher=None):
        self.name = name
        self.surname = surname
        self.number = number

        self.learner = learner
        self.teacher = teacher

jane = Person("Jane", "Smith", "SMTJNX045", Learner(), Teacher())
jane.learner.enrol(a_postgrad_course)
jane.teacher.assign_teaching(an_undergrad_course)

# %%
class Song:

    def __init__(self, title, artist, album, track_number):
        self.title = title
        self.artist = artist
        self.album = album
        self.track_number = track_number

        artist.add_song(self)


class Album:

    def __init__(self, title, artist, year):
        self.title = title
        self.artist = artist
        self.year = year

        self.tracks = []

        artist.add_album(self)

    def add_track(self, title, artist=None):
        if artist is None:
            artist = self.artist

        track_number = len(self.tracks)

        song = Song(title, artist, self, track_number)

        self.tracks.append(song)


class Artist:
    def __init__(self, name):
        self.name = name

        self.albums = []
        self.songs = []

    def add_album(self, album):
        self.albums.append(album)

    def add_song(self, song):
        self.songs.append(song)


class Playlist:
    def __init__(self, name):
        self.name = name
        self.songs = []

    def add_song(self, song):
        self.songs.append(song)

band = Artist("Bob's Awesome Band")
album = Album("Bob's First Single", band, 2013)
album.add_track("A Ballad about Cheese")
album.add_track("A Ballad about Cheese (dance remix)")
album.add_track("A Third Song to Use Up the Rest of the Space")

playlist = Playlist("My Favourite Songs")

for song in album.tracks:
    playlist.add_song(song)

# %%
class Box:
    def add(self, *items):
        raise NotImplementedError()

    def empty(self):
        raise NotImplementedError()

    def count(self):
        raise NotImplementedError()


class Item:
    def __init__(self, name, value):
        self.name = name
        self.value = value


class ListBox(Box):
    def __init__(self):
        self._items = []

    def add(self, *items):
        self._items.extend(items)

    def empty(self):
        items = self._items
        self._items = []
        return items

    def count(self):
        return len(self._items)


class DictBox(Box):
    def __init__(self):
        self._items = {}

    def add(self, *items):
        self._items.update(dict((i.name, i) for i in items))

    def empty(self):
        items = list(self._items.values())
        self._items = {}
        return items

    def count(self):
        return len(self._items)
--------------------------------------------
def repack_boxes(*boxes):
    items = []

    for box in boxes:
        items.extend(box.empty())

    while items:
        for box in boxes:
            try:
                box.add(items.pop())
            except IndexError:
                break

box1 = ListBox()
box1.add(Item(str(i), i) for i in range(20))

box2 = ListBox()
box2.add(Item(str(i), i) for i in range(9))

box1 = DictBox()
box1.add(Item(str(i), i) for i in range(5))

repack_boxes(box1, box2, box3)

print(box1.count())
print(box2.count())
print(box3.count())
